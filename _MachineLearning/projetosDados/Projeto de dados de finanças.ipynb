# %% [markdown]
# # Projeto de dados do mercado financeiro
#
# Neste projeto de dados, nos concentraremos na análise de dados exploratórios dos preços das ações. Tenha em mente que este projeto apenas pretende praticar suas habilidades de visualização e pandas, não é para ser uma análise financeira robusta ou ser tomado como um conselho financeiro.
# ____
# ** NOTA: Este projeto é extremamente desafiador, porque irá introduzir muitos novos conceitos e te fará procurar as coisas por conta própria (vamos apontar você na direção certa) para tentar resolver as tarefas emitidas. Sinta-se à vontade para passar pelo livro de conferências de soluções e no vídeo como um projeto "passo a passo" se você não quer ter que procurar as coisas sozinho. Você ainda aprenderá muito dessa forma! **
# ____
# Vamos nos concentrar nas ações dos banco e ver como eles performaram durante a [crise financeira](https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308) até o início de 2016.

# %% [markdown]
# ## Obter dados
#
# Nesta seção, aprenderemos a usar pandas para ler diretamente os dados das finanças do Google usando pandas!
#
# Primeiro, precisamos começar com as importações adequadas, que já apresentamos para você aqui.
#
# * Nota: [Você precisará instalar pandas-datareader para que isso funcione!](Https://github.com/pydata/pandas-datareader) O datareader Pandas permite que você [leia informações das ações diretamente da internet](http : //pandas.pydata.org/pandas-docs/stable/remote_data.html) Use estes links para orientação de instalação (** pip install pandas-datareader **), ou simplesmente acompanhe a conferência de vídeo. *
#
# ### Os Imports
#
# Já preenchidos para você.

# %%
pip install pandas-datareader
# Out:
# Collecting pandas-datareader
#   Downloading pandas_datareader-0.8.1-py2.py3-none-any.whl (107 kB)
# Requirement already satisfied: pandas>=0.21 in c:\users\gabriel\miniconda3\envs\estudo_mat\lib\site-packages (from pandas-datareader) (1.0.1)
# Requirement already satisfied: lxml in c:\users\gabriel\miniconda3\envs\estudo_mat\lib\site-packages (from pandas-datareader) (4.5.0)
# Collecting requests>=2.3.0
#   Downloading requests-2.23.0-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied: pytz>=2017.2 in c:\users\gabriel\miniconda3\envs\estudo_mat\lib\site-packages (from pandas>=0.21->pandas-datareader) (2019.3)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\gabriel\miniconda3\envs\estudo_mat\lib\site-packages (from pandas>=0.21->pandas-datareader) (1.18.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\gabriel\miniconda3\envs\estudo_mat\lib\site-packages (from pandas>=0.21->pandas-datareader) (2.8.1)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gabriel\miniconda3\envs\estudo_mat\lib\site-packages (from requests>=2.3.0->pandas-datareader) (2019.11.28)
# Collecting idna<3,>=2.5
#   Downloading idna-2.9-py2.py3-none-any.whl (58 kB)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.9-py2.py3-none-any.whl (126 kB)
# Requirement already satisfied: six>=1.5 in c:\users\gabriel\miniconda3\envs\estudo_mat\lib\site-packages (from python-dateutil>=2.6.1->pandas>=0.21->pandas-datareader) (1.14.0)
# Installing collected packages: chardet, idna, urllib3, requests, pandas-datareader
# Successfully installed chardet-3.0.4 idna-2.9 pandas-datareader-0.8.1 requests-2.23.0 urllib3-1.25.9
# Note: you may need to restart the kernel to use updated packages.

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline
# Out:
# C:\Users\Gabriel\Miniconda3\envs\estudo_mat\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %% [markdown]
# ## Dados
#
# Precisamos obter dados usando o datareader de pandas. Obteremos informações sobre ações para os seguintes bancos:
# * Bank of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo
#
# ** Descubra como obter os dados de ações de 1 de janeiro de 2006 a 1º de janeiro de 2016 para cada um desses bancos. Defina cada banco como um dataframe separado, com o nome da variável para que esse banco seja seu símbolo de ticker. Isso envolverá algumas etapas: **
# 1. Use datetime para definir objetos de início e fim de data e hora.
# 2. Descobrir o símbolo do ticker para cada banco.
# 2. Descubra como usar o datareader para pegar as cotações.
#
# ** Use [esta página de documentação](http://pandas.pydata.org/pandas-docs/stable/remote_data.html) para obter dicas e instruções. Use o google finance como um fonte, por exemplo: **
#
#      # Banco da América
#      BAC = data.DataReader ("BAC", "google", início e fim)

# %%
start = datetime.datetime(2006, 1, 1)
end = datetime.datetime(2016, 1, 1)

# %%
print(start)
# Out:
# 2006-01-01 00:00:00

# %%
#Bank of America
BAC = data.DataReader('BAC', data_source='yahoo', start= '2006-01-01', end= '2016-01-01')
BAC
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  35.298687
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  34.923801
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  34.968796
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  34.916302
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  34.938789
# ...               ...        ...        ...        ...         ...        ...
# 2015-12-24  17.379999  17.219999  17.320000  17.270000  29369400.0  15.969635
# 2015-12-28  17.230000  16.980000  17.219999  17.129999  41777500.0  15.840177
# 2015-12-29  17.350000  17.160000  17.250000  17.280001  45670400.0  15.978883
# 2015-12-30  17.240000  17.040001  17.200001  17.049999  35066400.0  15.766198
# 2015-12-31  17.070000  16.830000  17.010000  16.830000  47153000.0  15.562767
#
# [2517 rows x 6 columns]

# %%
C = data.DataReader('C', data_source='yahoo', start= start, end= end)

GS = data.DataReader('GS', data_source='yahoo', start= start, end= end)

JPM = data.DataReader('JPM', data_source='yahoo', start= start, end= end)

MS = data.DataReader('MS', data_source='yahoo', start= start, end= end)

WFC = data.DataReader('WFC', data_source='yahoo', start= start, end= end)

# %% [markdown]
# ** Crie uma lista dos símbolos dos tickers (como strings) em ordem alfabética. Chame esta lista: tickers **

# %%
tickers = ['C', 'GS', 'JPM', 'MS', 'WFC', 'BAC']
tickers = sorted(tickers)
tickers
# Out:
# ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %% [markdown]
# ** Use pd.concat para concatenar os DataFrames do banco juntos em um único chamado bank_stocks. Defina o argumento das chaves igual à lista de tickers. Também preste atenção em que eixo você concatena. **

# %%
bank_stocks = pd.concat([BAC, C, GS, JPM, MS, WFC], axis=1, keys = tickers)
bank_stocks
# Out:
#                   BAC                                                          \
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  35.298687
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  34.923801
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  34.968796
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  34.916302
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  34.938789
# ...               ...        ...        ...        ...         ...        ...
# 2015-12-24  17.379999  17.219999  17.320000  17.270000  29369400.0  15.969635
# 2015-12-28  17.230000  16.980000  17.219999  17.129999  41777500.0  15.840177
# 2015-12-29  17.350000  17.160000  17.250000  17.280001  45670400.0  15.978883
# 2015-12-30  17.240000  17.040001  17.200001  17.049999  35066400.0  15.766198
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.4  487.8  484.0  486.2
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.0  487.4  483.0  483.9
#
# Bank Ticker             ...        MS                                  WFC  \
# Stock Info    Volume    ...      Open   High    Low  Close   Volume   Open
# Date                    ...
# 2006-01-03   1537660    ...     57.17  58.49  56.74  58.31  5377000  31.60
# 2006-01-04   1871020    ...     58.70  59.28  58.35  58.35  7977800  31.80
# 2006-01-05   1143160    ...     58.55  58.59  58.02  58.51  5778000  31.50
# 2006-01-06   1370250    ...     58.77  58.85  58.05  58.57  6889800  31.58
# 2006-01-09   1680740    ...     58.63  59.29  58.62  59.19  4144500  31.68
#
# Bank Ticker
# Stock Info    High    Low  Close    Volume
# Date
# 2006-01-03   31.98  31.20  31.90  11016400
# 2006-01-04   31.82  31.36  31.53  10871000
# 2006-01-05   31.56  31.31  31.50  10158000
# 2006-01-06   31.78  31.38  31.68   8403800
# 2006-01-09   31.82  31.56  31.68   5619600
#
# [5 rows x 30 columns]

# %% [markdown]
# # Análise de dados exploratória
#
# Vamos explorar os dados um pouco! Antes de prosseguir, sugiro que você verifique a documentação no [Multi-Level Indexing](http://pandas.pydata.org/pandas-docs/stable/advanced.html) e [como usar .xs](http: // pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html).
# Consulte as soluções se você não consiga descobrir como usar .xs (), uma vez que isso será uma parte importante desse projeto.
#
# ** Qual é o preço máximo de fechamento para cada banco durante todo o período? **

# %%
bank_stocks.head(2)
# Out:
# Bank Ticker        BAC                                               \
# Stock Info        High        Low       Open      Close      Volume
# Date
# 2006-01-03   47.180000  46.150002  46.919998  47.080002  16296700.0
# 2006-01-04   47.240002  46.450001  47.000000  46.580002  17757900.0
#
# Bank Ticker                      C                                      ...  \
# Stock Info   Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2006-01-03   35.298687  493.799988  481.100006  490.000000  492.899994  ...
# 2006-01-04   34.923801  491.000000  483.500000  488.600006  483.799988  ...
#
# Bank Ticker         MS                                      WFC          \
# Stock Info        Open      Close     Volume  Adj Close    High     Low
# Date
# 2006-01-03   57.169998  58.310001  5377000.0  37.758644  31.975  31.195
# 2006-01-04   58.700001  58.349998  7977800.0  37.784546  31.820  31.365
#
# Bank Ticker
# Stock Info        Open      Close      Volume  Adj Close
# Date
# 2006-01-03   31.600000  31.900000  11016400.0  20.823185
# 2006-01-04   31.799999  31.530001  10870000.0  20.581659
#
# [2 rows x 36 columns]

# %%
bank_stocks.xs('Close', axis=1, level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     70.080002
# MS      89.300003
# WFC     58.520000
# dtype: float64

# %% [markdown]
# ** Crie um novo DataFrame vazio chamado returns. Este dataframe conterá os retornos para o ação de cada banco. Os retornos geralmente são definidos por: **
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
returns= pd.DataFrame()

# %%
bank_stocks['BAC']['Close']
# Out:
# Date
# 2006-01-03    47.080002
# 2006-01-04    46.580002
# 2006-01-05    46.639999
# 2006-01-06    46.570000
# 2006-01-09    46.599998
#                 ...
# 2015-12-24    17.270000
# 2015-12-28    17.129999
# 2015-12-29    17.280001
# 2015-12-30    17.049999
# 2015-12-31    16.830000
# Name: Close, Length: 2517, dtype: float64

# %%
bank_stocks['BAC']['Close'].pct_change()
# Out:
# Date
# 2006-01-03         NaN
# 2006-01-04   -0.010620
# 2006-01-05    0.001288
# 2006-01-06   -0.001501
# 2006-01-09    0.000644
#                 ...
# 2015-12-24   -0.004037
# 2015-12-28   -0.008107
# 2015-12-29    0.008757
# 2015-12-30   -0.013310
# 2015-12-31   -0.012903
# Name: Close, Length: 2517, dtype: float64

# %% [markdown]
# ** Podemos usar o método pct_change () pandas na coluna close para criar uma coluna que represente esse valor de retorno. Crie um loop for que vá e para cada Bank Stock Ticker cria essa coluna de retorno e configura-a como uma coluna nos dados DataFrame. **

# %%
# .pct_change() : Alteração percentual entre o elemento atual e o anterior ('retorno')

for cada in tickers:
    returns[cada+' return'] = bank_stocks[cada]['Close'].pct_change()

returns
# Out:
#             BAC return  C return  GS return  JPM return  MS return  WFC return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005874
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586   -0.000158
# ...                ...       ...        ...         ...        ...         ...
# 2015-12-24   -0.004037  0.001520  -0.002624   -0.001948  -0.003681   -0.003997
# 2015-12-28   -0.008107 -0.006261  -0.004658   -0.003303  -0.009544   -0.002554
# 2015-12-29    0.008757  0.011455   0.010516    0.010395   0.011812    0.011156
# 2015-12-30   -0.013310 -0.012835  -0.008282   -0.007157  -0.009831   -0.007235
# 2015-12-31   -0.012903 -0.010516  -0.009780   -0.008410  -0.013031   -0.009656
#
# [2517 rows x 6 columns]

# %%
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.000951
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005714
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586    0.000000

# %% [markdown]
# ** Crie um parplot utilizando seaborn no dataframe de retorno. **

# %%
import seaborn as sea

# %%
sea.pairplot(returns)

# %% [markdown]
# ** Usando o seu DataFrame returns, descubra quais datas cada ação dos bancos teve o melhor e o pior dia de retorno. Você deve notar que 4 dos bancos compartilham o mesmo dia para a pior queda. Alguma coisa significante aconteceu naquele dia? **

# %%
returns
# Out:
#             BAC return  C return  GS return  JPM return  MS return  WFC return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005874
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586   -0.000158
# ...                ...       ...        ...         ...        ...         ...
# 2015-12-24   -0.004037  0.001520  -0.002624   -0.001948  -0.003681   -0.003997
# 2015-12-28   -0.008107 -0.006261  -0.004658   -0.003303  -0.009544   -0.002554
# 2015-12-29    0.008757  0.011455   0.010516    0.010395   0.011812    0.011156
# 2015-12-30   -0.013310 -0.012835  -0.008282   -0.007157  -0.009831   -0.007235
# 2015-12-31   -0.012903 -0.010516  -0.009780   -0.008410  -0.013031   -0.009656
#
# [2517 rows x 6 columns]

# %%
returns[returns['BAC return'] == returns['BAC return'].min()]
# Out:
#             BAC return  C return  GS return  JPM return  MS return  WFC return
# Date
# 2009-01-20   -0.289694      -0.2  -0.189596   -0.207274  -0.159718   -0.238223

# %%
returns.idxmin()
# Out:
# BAC return   2009-01-20
# C return     2009-02-27
# GS return    2009-01-20
# JPM return   2009-01-20
# MS return    2008-10-09
# WFC return   2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BAC return   2009-04-09
# C return     2008-11-24
# GS return    2008-11-24
# JPM return   2009-01-21
# MS return    2008-10-13
# WFC return   2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
#  Obama foi eleito presidente em 2009-01-20

# %% [markdown]
# ** Dê uma olhada no desvio padrão dos retornos. Qual ação você classificaria como a mais arriscada durante todo o período de tempo? Qual você classificaria como a mais arriscado para o ano 2015? **

# %%
returns.std()                                                  # Mais arriscada seria 'C'
# Out:
# BAC return    0.036647
# C return      0.038672
# GS return     0.025390
# JPM return    0.027667
# MS return     0.037819
# WFC return    0.030238
# dtype: float64

# %%
# Out:
# BAC Return    0.036650
# C Return      0.179969
# GS Return     0.025346
# JPM Return    0.027656
# MS Return     0.037820
# WFC Return    0.030233
# dtype: float64

# %%
returns2015 = returns.loc['2015-01-01':'2015-12-31']            # Mais arriscada seria 'MS'
returns2015.std()
# Out:
# BAC return    0.016163
# C return      0.015289
# GS return     0.014046
# JPM return    0.014017
# MS return     0.016249
# WFC return    0.012591
# dtype: float64

# %%
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %% [markdown]
# ** Crie um distplot usando seaborn dos retornos de 2015 para Morgan Stanley **

# %%
sea.distplot(returns2015['MS return'], bins=200)

# %%
# Out:
# /Users/marci/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %% [markdown]
# ** Crie um distplot usando seaborn dos retornos de 2008 para CitiGroup **

# %%
sea.distplot(returns.loc['2008-01-01':'2008-12-31']['C return'], bins = 100, color='red')

# %%
# Out:
# /Users/marci/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %% [markdown]
# # Mais visualização
#
# Muito desse projeto se concentrará em visualizações. Sinta-se livre para usar qualquer uma das suas bibliotecas de visualização preferidas para tentar recriar os plots descritos abaixo, seaborn, matplotlib, plotly e cufflinks, ou apenas pandas.
#
# ### Importações

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %% [markdown]
# ** Crie um gráfico de linha mostrando o preço de fechamento para cada banco para todo o índice de tempo. (Sugestão: tente usar um loop for ou use [.xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html) para obter uma seção transversal dos dados .) **

# %%
closeDF = bank_stocks.xs('Close',axis=1, level= 'Stock Info')
closeDF
# Out:
# Bank Ticker        BAC           C          GS        JPM         MS  \
# Date
# 2006-01-03   47.080002  492.899994  128.869995  40.189999  58.310001
# 2006-01-04   46.580002  483.799988  127.089996  39.619999  58.349998
# 2006-01-05   46.639999  486.200012  127.040001  39.740002  58.509998
# 2006-01-06   46.570000  486.200012  128.839996  40.020000  58.570000
# 2006-01-09   46.599998  483.899994  130.389999  40.669998  59.189999
# ...                ...         ...         ...        ...        ...
# 2015-12-24   17.270000   52.709999  182.470001  66.599998  32.480000
# 2015-12-28   17.129999   52.380001  181.619995  66.379997  32.169998
# 2015-12-29   17.280001   52.980000  183.529999  67.070000  32.549999
# 2015-12-30   17.049999   52.299999  182.009995  66.589996  32.230000
# 2015-12-31   16.830000   51.750000  180.229996  66.029999  31.809999
#
# Bank Ticker        WFC
# Date
# 2006-01-03   31.900000
# 2006-01-04   31.530001
# 2006-01-05   31.495001
# 2006-01-06   31.680000
# 2006-01-09   31.674999
# ...                ...
# 2015-12-24   54.820000
# 2015-12-28   54.680000
# 2015-12-29   55.290001
# 2015-12-30   54.889999
# 2015-12-31   54.360001
#
# [2517 rows x 6 columns]

# %%
closeDF.plot(figsize= (20,10))

# %% [markdown]
# ## Médias móveis
#
# Vamos analisar as médias móveis para essas ações no ano de 2008.
#
# ** Trace a média de 30 dias para o preço do Bank Of America para o ano de 2008 **

# %%
closeDF
# Out:
# Bank Ticker        BAC           C          GS        JPM         MS  \
# Date
# 2006-01-03   47.080002  492.899994  128.869995  40.189999  58.310001
# 2006-01-04   46.580002  483.799988  127.089996  39.619999  58.349998
# 2006-01-05   46.639999  486.200012  127.040001  39.740002  58.509998
# 2006-01-06   46.570000  486.200012  128.839996  40.020000  58.570000
# 2006-01-09   46.599998  483.899994  130.389999  40.669998  59.189999
# ...                ...         ...         ...        ...        ...
# 2015-12-24   17.270000   52.709999  182.470001  66.599998  32.480000
# 2015-12-28   17.129999   52.380001  181.619995  66.379997  32.169998
# 2015-12-29   17.280001   52.980000  183.529999  67.070000  32.549999
# 2015-12-30   17.049999   52.299999  182.009995  66.589996  32.230000
# 2015-12-31   16.830000   51.750000  180.229996  66.029999  31.809999
#
# Bank Ticker        WFC
# Date
# 2006-01-03   31.900000
# 2006-01-04   31.530001
# 2006-01-05   31.495001
# 2006-01-06   31.680000
# 2006-01-09   31.674999
# ...                ...
# 2015-12-24   54.820000
# 2015-12-28   54.680000
# 2015-12-29   55.290001
# 2015-12-30   54.889999
# 2015-12-31   54.360001
#
# [2517 rows x 6 columns]

# %%
closeDF2008 = closeDF.loc['2008-01-01':'2008-12-31']

BABAC = closeDF2008['BAC']
BAC_window30 = closeDF2008['BAC'].rolling(window=30).mean()
BABAC.plot()
BAC_window30.plot(figsize=(20,5)).legend()

# %% [markdown]
# ** Crie um mapa de calor da correlação entre os preços de fechamento das ações. **

# %%
sea.heatmap(closeDF.corr(), cmap='RdBu_r', annot=True)

# %% [markdown]
# ** Opcional: use o clustermap do seaborn para agrupar as correlações: **

# %% [markdown]
# Definitivamente, muitos tópicos de finanças específicos aqui, então não se preocupe se você não os entendeu todos! A única coisa que você deve estar preocupado com a compreensão são os pandas básicos e operações de visualização.
