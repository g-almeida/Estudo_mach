# %% [markdown]
# 1!) While
#     break
#
# 2!)For each in list:

# %%
#list0 = [0, 1, 2, 3, 4 , 5, 6, 7]
x = 0
while x < 4:
    x = x + 1
    print(x)
# Out:
# 1
# 2
# 3
# 4

# %%
list0 = [0, 1 , 2 ,3 ,4 , 5, 6]
list1 = []
for each in list0:
    each = each+0.5
    list1.append(each)
    print(each)
# Out:
# 0.5
# 1.5
# 2.5
# 3.5
# 4.5
# 5.5
# 6.5

# %%
list1
# Out:
# [0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5]

# %%
print("PALÍNDROMOS")
x = 1000
var = int(input("qhats the value of var:"))
while x <= var:
    a = str(x)
    if a[0] == a[3] and a[1] == a[2]:
        print(x)
    x += 1

    
def ahmedfunction():
    return value
# Out:
# PALÍNDROMOS
# qhats the value of var: 5555
# 1001
# 1111
# 1221
# 1331
# 1441
# 1551
# 1661
# 1771
# 1881
# 1991
# 2002
# 2112
# 2222
# 2332
# 2442
# 2552
# 2662
# 2772
# 2882
# 2992
# 3003
# 3113
# 3223
# 3333
# 3443
# 3553
# 3663
# 3773
# 3883
# 3993
# 4004
# 4114
# 4224
# 4334
# 4444
# 4554
# 4664
# 4774
# 4884
# 4994
# 5005
# 5115
# 5225
# 5335
# 5445
# 5555

# %%
var = input("qhats the value of var:")
type(var)
# Out:
# qhats the value of var: 545243
# str

# %%
string_a = str(a)

# %%
string_a[3]
# Out:
# '1'

# %%
def writ_name(arg0):
    print(arg0)
    name = arg0
    return name

# %%
a = input("whats my name")
print(a)
# Out:
# whats my name Gab
# Gab

# %%
# Out:
# Gab
# 'Gab'

# %%
b = input("whats my name")
print(b)
v = writ_name(b)
# Out:
# whats my name Ahmed
# Ahmed
# Ahmed

# %%
v
# Out:
# 'Ahmed'
