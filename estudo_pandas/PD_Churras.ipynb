# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sea

# %%
df = pd.read_excel('D:/_Gabriel/Estudo/ProgramaçãoGeral/Excel/PD_churras.xlsx')
df.rename(columns={'Unnamed: 10':'Valores'}, inplace=True)
df
# Out:
#      Nomes:  Comida  Bebida  Extras  Já pagou  Total individual:     Falta:  \
# 0       Gab     1.0     0.0     1.0     100.0          54.333333 -45.666667
# 1     Diogo     1.0     1.0     1.0     130.0          84.333333 -45.666667
# 2        Fe     0.0     1.0     0.0     125.0          30.000000 -95.000000
# 3    Gustin     1.0     0.0     1.0      55.0          54.333333  -0.666667
# 4       Rod     0.0     0.0     1.0      20.0           8.333333 -11.666667
# 5      Rafa     1.0     1.0     0.0       0.0          76.000000  76.000000
# 6       Jun     1.0     1.0     1.0       0.0          84.333333  84.333333
# 7    Pedrin     0.0     1.0     1.0       0.0          38.333333  38.333333
# 8       NaN     NaN     NaN     NaN       NaN           0.000000   0.000000
# 9       NaN     NaN     NaN     NaN       NaN           0.000000   0.000000
# 10      NaN     NaN     NaN     NaN       NaN           0.000000   0.000000
# ...

# %%
def primeiroVazio(data):
    nulo = df['Nomes:'].isnull()
    count = 0
    for cada in nulo:
        if cada == False:
            count+=1
        else:
            return count

# %%
def addCria(data):
    DF = data
    
    cria = str(input('Entre com o nome do cria:'))
    Comeu = int(input('Comeu? (1 pra sim, 0 pra não)'))
    Bebeu = int(input('Bebeu? (1 pra sim, 0 pra não)'))
    hihi = int(input('Extra? (1 pra sim, 0 pra não)'))
    pagou = float(input('Já pagou quanto?'))
    
    totalC = DF['Valores'][0]
    totalB = DF['Valores'][1]
    totalE = DF['Valores'][2]
    
    n = primeiroVazio(data)
    #DF.iloc[n] = {cria,Comeu,Bebeu,extra,pagou,0,0,0,0,0,0,0}
    DF.iloc[n] = {cria : 'eu', Comeu : 2, 'Bug' : 3, hihi :4, 'Já pagou':5, 'Total individual:':0, 'Falta:':0, 'Unnamed: 7':0,'Unnamed: 8':0,'Unnamed: 9':0,'Valores':0,'Dividindo:':0}

# %%
a = {'cria' : 'cria', 'Comeu': 'Comeu', 'Bebeu': 'Bebeu', 'hihi' : 0, 'pagou': 'pagou', 'Total individual:':0, 'Falta:':0, 'Unnamed: 7':0,'Unnamed: 8':0,'Unnamed: 9':0,'Valores':0,'Dividindo:':0}
a
# Out:
# {'cria': 'cria',
#  'Comeu': 'Comeu',
#  'Bebeu': 'Bebeu',
#  'hihi': 0,
#  'pagou': 'pagou',
#  'Total individual:': 0,
#  'Falta:': 0,
#  'Unnamed: 7': 0,
#  'Unnamed: 8': 0,
#  'Unnamed: 9': 0,
#  'Valores': 0,
#  'Dividindo:': 0}

# %%
df.iloc[10] = {'Nomes:': 'eu', 'Comida': 2,'Bebida': 3, 'Extras':4, 'Já pagou':5, 'Total individual:':0, 'Falta:':0, 'Unnamed: 7':0,'Unnamed: 8':0,'Unnamed: 9':0,'Valores':0,'Dividindo:':0}

# %%
df
# Out:
#      Nomes:  Comida  Bebida  Extras  Já pagou  Total individual:    Falta:  \
# 0       Gab       1       0       1       100            54.3333  -45.6667
# 1     Diogo       1       1       1       130            84.3333  -45.6667
# 2        Fe       0       1       0       125                 30       -95
# 3    Gustin       1       0       1        55            54.3333 -0.666667
# 4       Rod       0       0       1        20            8.33333  -11.6667
# 5      Rafa       1       1       0         0                 76        76
# 6       Jun       1       1       1         0            84.3333   84.3333
# 7    Pedrin       0       1       1         0            38.3333   38.3333
# 8       NaN     NaN     NaN     NaN       NaN                  0         0
# 9       NaN     NaN     NaN     NaN       NaN                  0         0
# 10   Nomes:  Comida  Bebida  Extras  Já pagou  Total individual:    Falta:
# ...

# %%
primeiroVazio(df)
# Out:
# 10

# %%
addCria(df)
# Out:
# Entre com o nome do cria:ate amn
# Comeu? (1 pra sim, 0 pra não)1
# Bebeu? (1 pra sim, 0 pra não)0
# Extra? (1 pra sim, 0 pra não)1
# Já pagou quanto?25
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-02cd9bb77ce5> in <module>
# ----> 1 addCria(df)
#
# <ipython-input-87-b517f52ec0c7> in addCria(data)
#      14     n = primeiroVazio(data)
#      15     #DF.iloc[n] = {cria,Comeu,Bebeu,extra,pagou,0,0,0,0,0,0,0}
# ---> 16     DF.iloc[n] = {cria : 'eu', Comeu : 2, 'Bug' : 3, hihi :4, 'Já pagou':5, 'Total individual:':0, 'Falta:':0, 'Unnamed: 7':0,'Unnamed: 8':0,'Unnamed: 9':0,'Valores':0,'Dividindo:':0}
#
# ~\miniconda3\envs\bloqueios\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     669             key = com.apply_if_callable(key, self.obj)
#     670         indexer = self._get_setitem_indexer(key)
# ...

# %%
df
# Out:
#      Nomes:  Comida  Bebida  Extras  Já pagou  Total individual:    Falta:  \
# 0       Gab     1.0       0     1.0       100            54.3333  -45.6667
# 1     Diogo     1.0       1     1.0       130            84.3333  -45.6667
# 2        Fe     0.0       1     0.0       125                 30       -95
# 3    Gustin     1.0       0     1.0        55            54.3333 -0.666667
# 4       Rod     0.0       0     1.0        20            8.33333  -11.6667
# 5      Rafa     1.0       1     0.0         0                 76        76
# 6       Jun     1.0       1     1.0         0            84.3333   84.3333
# 7    Pedrin     0.0       1     1.0         0            38.3333   38.3333
# 8     nepos     1.0  Bebida     0.0  Já pagou  Total individual:    Falta:
# 9       bra     1.0  Bebida     0.0  Já pagou  Total individual:    Falta:
# 10      NaN     NaN     NaN     NaN       NaN                  0         0
# ...
