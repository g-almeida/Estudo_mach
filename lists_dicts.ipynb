# %%
data = {'Company':['GOOG','GOOG', 'MSFT','MSFT','FB','FB'],
        'Names':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
        'Prices':[200,120,340,124,243,350]}

# %%
var = 'word'

# %%
var[1:]
# Out:
# 'ord'

# %%
var[:-3]
# Out:
# 'w'

# %%
a_List = ['Sam','Charlie','Amy','Vanessa','Carl','Sarah']

# %%
a_List[1:3]
# Out:
# ['Charlie', 'Amy']

# %%
a_List[1:3]
# Out:
# ['Charlie', 'Amy']

# %%
a_List[1:3][0]
# Out:
# 'Charlie'

# %%
a_List[1:3][0][1]
# Out:
# 'h'

# %%
a_List[1:3]+a_List[3:6]
# Out:
# ['Charlie', 'Amy', 'Vanessa', 'Carl', 'Sarah']

# %% [markdown]
# lists = []
# dictionary = {}
#
# dictionary = {key : values}

# %%
dc = {'arpoador':["gab", 'ahmed', 'leo'], 'p11':['hugo','bernardo','miami']}
dc
# Out:
# {'arpoador': ['gab', 'ahmed', 'leo'], 'p11': ['hugo', 'bernardo', 'miami']}

# %%
dc['arpoador']
# Out:
# ['gab', 'ahmed', 'leo']

# %% [markdown]
# "MÉTODOS ÚTEIS: get() /  pesquisa com 'in' para membros do dicionário e 'values' para seus valores / 'del' "

# %%
dc.update({"copacabana":['diogo','julian']})

# %%
dc
# Out:
# {'arpoador': ['kelly', 'jjf'], 'p11': ['hugo', 'bernardo', 'miami']}

# %%
dc
# Out:
# {'arpoador': ['kelly', 'jjf'],
#  'p11': ['hugo', 'bernardo', 'miami'],
#  'copacabana': ['diogo', 'julian']}

# %%
def ahmed_function():
    return "hey I'm Ahmed"

# %%
ahmed_function()
# Out:
# "hey I'm Ahmed"

# %%
var2 = 29

# %%
if var2 == 26:
    print("It's ok")
elif var2 == 23:
    print("Also ok")
elif var2 ==25:
    print('var=25')
elif var2 == 27:  
    print('var=27')
else:
    print('wrong')
# Out:
# wrong

# %%
var2 = 30

# %%
if var2 != 30:
    print('var2 is not 29')
else:
    print("ok var2 is 30")
# Out:
# ok var2 is 30
