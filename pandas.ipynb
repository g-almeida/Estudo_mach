# %%
import pandas as pd
import numpy as np

# %%
a = [[1,2,3],[4,5,6],[5,3,2312131262345523]]
np.array(a).shape
# Out:
# (3, 3)

# %% [markdown]
# # Pandas objects
# ## Series

# %%
dict_ex = {'gab':[45,12] ,'jun':[23,77], 'mike':[78,92], 'diego':[66,99]}
the_serie = pd.Series(dict_ex)
the_serie
# Out:
# gab      [45, 12]
# jun      [23, 77]
# mike     [78, 92]
# diego    [66, 99]
# dtype: object

# %%
the_serie[0]
# Out:
# [45, 12]

# %% [markdown]
# ## DataFrames

# %%
df = pd.DataFrame({'ahmed':[1,2,3,4,5]})
serie_ = pd.Series({'ahmed':[1,2,3,4,5]})

# %%
serie_.index
# Out:
# Index(['ahmed'], dtype='object')

# %%
df
# Out:
#    ahmed
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5

# %%
dict_ex
# Out:
# {'gab': [45, 12], 'jun': [23, 77], 'mike': [78, 92], 'diego': [66, 99]}

# %%
df2 = pd.DataFrame(dict_ex)
df2.plot()
# Out:
# <AxesSubplot:>

# %%
df_911 = pd.read_csv('./data/911.csv', delimiter=',')
new_df = df_911.set_index('zip')
new_df.to_csv("")
# Out:
#                lat        lng  \
# zip
# 19525.0  40.297876 -75.581294
# 19446.0  40.258061 -75.264680
# 19401.0  40.121182 -75.351975
# 19401.0  40.116153 -75.343513
# NaN      40.251492 -75.603350
# ...            ...        ...
# 19401.0  40.132869 -75.333515
# 19003.0  40.006974 -75.289080
# 19401.0  40.115429 -75.334679
# 19002.0  40.186431 -75.192555
# 19446.0  40.207055 -75.317952
#
#                                                       desc  \
# zip
# 19525.0  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 19446.0  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 19401.0  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 19401.0  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# NaN      CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
# ...                                                    ...
# 19401.0  MARKLEY ST & W LOGAN ST; NORRISTOWN; 2016-08-2...
# 19003.0  LANCASTER AVE & RITTENHOUSE PL; LOWER MERION; ...
# 19401.0  CHESTNUT ST & WALNUT ST;  NORRISTOWN; Station ...
# 19002.0  WELSH RD & WEBSTER LN;  HORSHAM; Station 352; ...
# 19446.0  MORRIS RD & S BROAD ST; UPPER GWYNEDD; 2016-08...
#
#                                title            timeStamp                twp  \
# zip
# 19525.0       EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 19446.0      EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 19401.0          Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00         NORRISTOWN
# 19401.0       EMS: CARDIAC EMERGENCY  2015-12-10 17:40:01         NORRISTOWN
# NaN                   EMS: DIZZINESS  2015-12-10 17:40:01   LOWER POTTSGROVE
# ...                              ...                  ...                ...
# 19401.0  Traffic: VEHICLE ACCIDENT -  2016-08-24 11:06:00         NORRISTOWN
# 19003.0  Traffic: VEHICLE ACCIDENT -  2016-08-24 11:07:02       LOWER MERION
# 19401.0             EMS: FALL VICTIM  2016-08-24 11:12:00         NORRISTOWN
# 19002.0         EMS: NAUSEA/VOMITING  2016-08-24 11:17:01            HORSHAM
# 19446.0  Traffic: VEHICLE ACCIDENT -  2016-08-24 11:17:02      UPPER GWYNEDD
#
#                                    addr  e
# zip
# 19525.0          REINDEER CT & DEAD END  1
# 19446.0      BRIAR PATH & WHITEMARSH LN  1
# 19401.0                        HAWS AVE  1
# 19401.0              AIRY ST & SWEDE ST  1
# NaN            CHERRYWOOD CT & DEAD END  1
# ...                                 ... ..
# 19401.0         MARKLEY ST & W LOGAN ST  1
# 19003.0  LANCASTER AVE & RITTENHOUSE PL  1
# 19401.0         CHESTNUT ST & WALNUT ST  1
# 19002.0           WELSH RD & WEBSTER LN  1
# 19446.0          MORRIS RD & S BROAD ST  1
#
# [99492 rows x 8 columns]

# %%
df_911['title'].apply(lambda x: x.split(':'))
# Out:
# 0             [EMS,  BACK PAINS/INJURY]
# 1            [EMS,  DIABETIC EMERGENCY]
# 2                [Fire,  GAS-ODOR/LEAK]
# 3             [EMS,  CARDIAC EMERGENCY]
# 4                     [EMS,  DIZZINESS]
#                       ...
# 99487    [Traffic,  VEHICLE ACCIDENT -]
# 99488    [Traffic,  VEHICLE ACCIDENT -]
# 99489               [EMS,  FALL VICTIM]
# 99490           [EMS,  NAUSEA/VOMITING]
# 99491    [Traffic,  VEHICLE ACCIDENT -]
# Name: title, Length: 99492, dtype: object

# %% [markdown]
# ## Merge | Concat | Join

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                   'C': ['C0', 'C1', 'C2', 'C3'],
                   'D': ['D0', 'D1', 'D2', 'D3']},
                   index=[0, 1, 2, 3])

df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                       'B': ['B4', 'B5', 'B6', 'B7'],
                       'C': ['C4', 'C5', 'C6', 'C7'],
                       'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7])
   
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'],
                     'C': ['C8', 'C9', 'C10', 'C11'],
                      'D': ['D8', 'D9', 'D10', 'D11']},
                    index=[8, 9, 10, 11])

dicionario = {'ID':[10,11,12,13,14,],'NOME':['Mario','Joana','Claudia','Lucas','Gabriel'],
              'CIDADE':['SÃO PAULO','RIO DE JANEIRO','SÃO PAULO','CAMPINAS','PORTO ALEGRE']}
dicionario2 = {'ID':[16,11,12,13,18,],'Experiência':['Junior','Senior','Pleno','Estagiário','Analista']}

df4 = pd.DataFrame(data=dicionario)
df5 = pd.DataFrame(data=dicionario2)

dicionario = {'NOME':['Mario','Joana','Claudia','Lucas','Gabriel'],
              'CIDADE':['SÃO PAULO','RIO DE JANEIRO','SÃO PAULO','CAMPINAS','PORTO ALEGRE']}

dicionario2 = {'Experiência':['Junior','Senior','Pleno','Estagiário','Analista']}

df7 = pd.DataFrame(data=dicionario)
df8 = pd.DataFrame(data=dicionario2)

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
df4
# Out:
#    ID     NOME          CIDADE
# 0  10    Mario       SÃO PAULO
# 1  11    Joana  RIO DE JANEIRO
# 2  12  Claudia       SÃO PAULO
# 3  13    Lucas        CAMPINAS
# 4  14  Gabriel    PORTO ALEGRE

# %%
df5
# Out:
#    ID Experiência
# 0  16      Junior
# 1  11      Senior
# 2  12       Pleno
# 3  13  Estagiário
# 4  18    Analista

# %%
pd.merge(df4,df5)
# Out:
#    ID     NOME          CIDADE Experiência
# 0  11    Joana  RIO DE JANEIRO      Senior
# 1  12  Claudia       SÃO PAULO       Pleno
# 2  13    Lucas        CAMPINAS  Estagiário

# %%
pd.merge(df4,df5,how='outer')
# Out:
#    ID     NOME          CIDADE Experiência
# 0  10    Mario       SÃO PAULO         NaN
# 1  11    Joana  RIO DE JANEIRO      Senior
# 2  12  Claudia       SÃO PAULO       Pleno
# 3  13    Lucas        CAMPINAS  Estagiário
# 4  14  Gabriel    PORTO ALEGRE         NaN
# 5  16      NaN             NaN      Junior
# 6  18      NaN             NaN    Analista
